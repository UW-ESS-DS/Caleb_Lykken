# %%
#Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a series of random numbers using a numpy array
# Set the seed to 101
mydata = np.random.randint(0,101, (4,3))
mydata

# plot the data using matplotlib
plt.plot(mydata)

# save the plot as a png file
plt.savefig('myplot.png')
